# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\kouts\chicago-crime-de-pipeline\include\chicago_crimes.csv')
df.isnull().sum()
# Out:
# id                        0
# case_number               0
# date                      0
# block                     0
# iucr                      0
# primary_type              0
# description               0
# location_description    481
# arrest                    0
# domestic                  0
# beat                      0
# district                  0
# ward                      0
# community_area            2
# fbi_code                  0
# x_coordinate             72
# y_coordinate             72
# year                      0
# updated_on                0
# latitude                 72
# longitude                72
# location                 72
# dtype: int64

# %%
df['primary_type'].value_counts().head(10)
df['year'].value_counts().sort_index()
df['primary_type'].value_counts().head(10)
# Out:
# primary_type
# THEFT                  22171
# BATTERY                18197
# CRIMINAL DAMAGE        10906
# ASSAULT                 8946
# MOTOR VEHICLE THEFT     7974
# OTHER OFFENSE           6963
# DECEPTIVE PRACTICE      5817
# BURGLARY                5749
# NARCOTICS               2911
# CRIMINAL TRESPASS       2479
# Name: count, dtype: int64

# %%
df['district'].value_counts().head(10)
# Out:
# district
# 12    6607
# 8     6391
# 2     5691
# 6     5576
# 1     5566
# 3     5530
# 19    5467
# 4     5405
# 18    5384
# 11    5160
# Name: count, dtype: int64
